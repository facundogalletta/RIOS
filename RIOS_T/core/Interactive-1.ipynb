# %% [markdown]
# Connected to timag (Python 3.9.17)

# %%
from ArmadoMosAuxiliares import orientacion, str2lat_or_long_vec, LongLat2UTM, str2fraction, datetimeSTR2timeFLOAT, fracc_sec
from correction_distorted_img import calibration
from calibration_dji import calibration_dji
import micasense.capture as capture
from PIL.ExifTags import TAGS
from georectification_general import generacion_nueva_img_general
from interactive_windows import interactive_window, interactive_window_number,seleccionar_carpeta,seleccionar_csv,interactive_window_aviso
import numpy as np
import pandas as pd
from osgeo import gdal
from PIL import Image
from skimage.io import imread
import PySimpleGUI as sg

# %%
interactive_window_aviso(''''¡Note that there may be effects of borders
                
                La correccion se realiza mediante una "pendiente", que consiste en un valor que se agrego como acumulacion de errores y se
                debe restar a cada imagen tantas veces como la cantidad de fotos que haya entre la foto inicial y esta:
                
                Imagen correcta = Imagen uncorrecta * ( 1-pendiente * ( N° foto-N° foto inicial) ) )
                
                La ultima pendiente calibrada corresponde al ''' + fecha_pendiente_calibrada )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       1 interactive_window_aviso(''''¡Note that there may be effects of borders
#       2
#       3                 La correccion se realiza mediante una "pendiente", que consiste en un valor que se agrego como acumulacion de errores y se
#       4                 debe restar a cada imagen tantas veces como la cantidad de fotos que haya entre la foto inicial y esta:
#       5
#       6                 Imagen correcta = Imagen uncorrecta * ( 1-pendiente * ( N° foto-N° foto inicial) ) )
#       7
# ----> 8                 La ultima pendiente calibrada corresponde al ''' + fecha_pendiente_calibrada )
#
# NameError: name 'fecha_pendiente_calibrada' is not defined

# %%
pendiente_calibrada=-0.025#(22.36-22.18)/(65-238)+0.0001
fecha_pendiente_calibrada = '16/12/2020 - 14:00'

# %%
interactive_window_aviso(''''¡Note that there may be effects of borders
                
                La correccion se realiza mediante una "pendiente", que consiste en un valor que se agrego como acumulacion de errores y se
                debe restar a cada imagen tantas veces como la cantidad de fotos que haya entre la foto inicial y esta:
                
                Imagen correcta = Imagen uncorrecta * ( 1-pendiente * ( N° foto-N° foto inicial) ) )
                
                La ultima pendiente calibrada corresponde al ''' + fecha_pendiente_calibrada )

# %%
interactive_window_aviso(''''¡Note that there may be effects of borders!
                
                                La correccion se realiza mediante una "pendiente", que consiste en un valor que se agrego como acumulacion de errores y se
                                debe restar a cada imagen tantas veces como la cantidad de fotos que haya entre la foto inicial y esta:
                                
                                Imagen correcta = Imagen uncorrecta * ( 1-pendiente * ( N° foto-N° foto inicial) ) )
                                
                                La ultima pendiente calibrada corresponde al ''' + fecha_pendiente_calibrada )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 interactive_window_aviso(''''¡Note that there may be effects of borders!
#       2
#       3                                 La correccion se realiza mediante una "pendiente", que consiste en un valor que se agrego como acumulacion de errores y se
#       4                                 debe restar a cada imagen tantas veces como la cantidad de fotos que haya entre la foto inicial y esta:
#       5
#       6                                 Imagen correcta = Imagen uncorrecta * ( 1-pendiente * ( N° foto-N° foto inicial) ) )
#       7
#       8                                 La ultima pendiente calibrada corresponde al ''' + fecha_pendiente_calibrada )
#
# File d:\fgalletta\Codigos_Dron\codigos_de_0\interactive_windows.py:29, in interactive_window_aviso(parametro)
# ...

# %%
def interactive_window_aviso(parametro):
    layout = [[sg.Text(parametro, font=('Arial', 12), justification='center')],
              [sg.Button('Ok', size=(10, 1), pad=((25, 25), (10, 10)), font=('Arial', 12))]]

    window = sg.Window('Aviso', layout, finalize=True)
    window.BringToFront()

    while True:
        event, values = window.read()
        if event == sg.WINDOW_CLOSED or event == 'Ok':
            break

    window.close()

# %%
interactive_window_aviso(''''¡Note that there may be effects of borders!
                
                                La correccion se realiza mediante una "pendiente", que consiste en un valor que se agrego como acumulacion de errores y se
                                debe restar a cada imagen tantas veces como la cantidad de fotos que haya entre la foto inicial y esta:
                                
                                Imagen correcta = Imagen uncorrecta * ( 1-pendiente * ( N° foto-N° foto inicial) ) )
                                
                                La ultima pendiente calibrada corresponde al ''' + fecha_pendiente_calibrada )

# %%
def interactive_window_aviso(parametro):
    layout = [[sg.Text(parametro, font=('Arial', 12), justification='center')],
              [sg.Button('Ok', size=(10, 1), pad=((24, 25), (10, 10)), font=('Arial', 12))]]

    window = sg.Window('Aviso', layout, finalize=True)
    window.BringToFront()

    while True:
        event, values = window.read()
        if event == sg.WINDOW_CLOSED or event == 'Ok':
            break

    window.close()

# %%
interactive_window_aviso(''''¡Note that there may be effects of borders!
                
                                La correccion se realiza mediante una "pendiente", que consiste en un valor que se agrego como acumulacion de errores y se
                                debe restar a cada imagen tantas veces como la cantidad de fotos que haya entre la foto inicial y esta:
                                
                                Imagen correcta = Imagen uncorrecta * ( 1-pendiente * ( N° foto-N° foto inicial) ) )
                                
                                La ultima pendiente calibrada corresponde al ''' + fecha_pendiente_calibrada )

# %%
def interactive_window_aviso(parametro):
    layout = [[sg.Text(parametro, font=('Arial', 12), justification='center')],
              [sg.Button('Ok', size=(10, 1), pad=((20, 25), (10, 10)), font=('Arial', 12))]]

    window = sg.Window('Aviso', layout, finalize=True)
    window.BringToFront()

    while True:
        event, values = window.read()
        if event == sg.WINDOW_CLOSED or event == 'Ok':
            break

    window.close()

# %%
interactive_window_aviso(''''¡Note that there may be effects of borders!
                
                                La correccion se realiza mediante una "pendiente", que consiste en un valor que se agrego como acumulacion de errores y se
                                debe restar a cada imagen tantas veces como la cantidad de fotos que haya entre la foto inicial y esta:
                                
                                Imagen correcta = Imagen uncorrecta * ( 1-pendiente * ( N° foto-N° foto inicial) ) )
                                
                                La ultima pendiente calibrada corresponde al ''' + fecha_pendiente_calibrada )

# %%
def interactive_window_aviso(parametro):
    layout = [[sg.Text(parametro, font=('Arial', 12), justification='center')],
              [sg.Button('Ok', size=(10, 1), pad=((30, 25), (10, 10)), font=('Arial', 12))]]

    window = sg.Window('Aviso', layout, finalize=True)
    window.BringToFront()

    while True:
        event, values = window.read()
        if event == sg.WINDOW_CLOSED or event == 'Ok':
            break

    window.close()

# %%
interactive_window_aviso(''''¡Note that there may be effects of borders!
                
                                La correccion se realiza mediante una "pendiente", que consiste en un valor que se agrego como acumulacion de errores y se
                                debe restar a cada imagen tantas veces como la cantidad de fotos que haya entre la foto inicial y esta:
                                
                                Imagen correcta = Imagen uncorrecta * ( 1-pendiente * ( N° foto-N° foto inicial) ) )
                                
                                La ultima pendiente calibrada corresponde al ''' + fecha_pendiente_calibrada )

# %%
def interactive_window_aviso(parametro):
    layout = [[sg.Text(parametro, font=('Arial', 12), justification='center')],
              [sg.Button('Ok', size=(10, 1), pad=((20, 20), (10, 10)), font=('Arial', 12))]]

    window = sg.Window('Aviso', layout, finalize=True)
    window.BringToFront()

    while True:
        event, values = window.read()
        if event == sg.WINDOW_CLOSED or event == 'Ok':
            break

    window.close()

# %%
interactive_window_aviso(''''¡Note that there may be effects of borders!
                
                                La correccion se realiza mediante una "pendiente", que consiste en un valor que se agrego como acumulacion de errores y se
                                debe restar a cada imagen tantas veces como la cantidad de fotos que haya entre la foto inicial y esta:
                                
                                Imagen correcta = Imagen uncorrecta * ( 1-pendiente * ( N° foto-N° foto inicial) ) )
                                
                                La ultima pendiente calibrada corresponde al ''' + fecha_pendiente_calibrada )

# %%
def interactive_window_aviso(parametro):
    layout = [[sg.Text(parametro, font=('Arial', 12), justification='center')],
              [sg.Button('Ok', font=('Arial', 12), size=(10, 1), pad=((40, 40), (10, 10)))]]

    window = sg.Window('Aviso', layout, finalize=True)
    window.BringToFront()

    while True:
        event, values = window.read()
        if event == sg.WINDOW_CLOSED or event == 'Ok':
            break

    window.close()

# %%
interactive_window_aviso(''''¡Note that there may be effects of borders!
                
                                La correccion se realiza mediante una "pendiente", que consiste en un valor que se agrego como acumulacion de errores y se
                                debe restar a cada imagen tantas veces como la cantidad de fotos que haya entre la foto inicial y esta:
                                
                                Imagen correcta = Imagen uncorrecta * ( 1-pendiente * ( N° foto-N° foto inicial) ) )
                                
                                La ultima pendiente calibrada corresponde al ''' + fecha_pendiente_calibrada )
